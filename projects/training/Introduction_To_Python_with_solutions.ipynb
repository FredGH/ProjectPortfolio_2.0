# %% [markdown]
# ## Set Lib Path

# %% [markdown]
# ## Import Libraries

# %%
from IPython.display import display
import numpy as np
import pandas as pd
import seaborn as sbn
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from geopy.geocoders import Nominatim
import folium

#Show graph in line
# %matplotlib inline 

print ("All dependent libs have been loaded.")
# Out:
# All dependent libs have been loaded.

# %% [markdown]
# ## Hello World

# %%
print ("hello world")
# Out:
# hello world

# %% [markdown]
# ## 0. Basic Concepts

# %% [markdown]
# ### For loops

# %%
print ("Exmaple 1")
for friend in ['Margot', 'Kathryn', 'Prisila']:
    invitation = "Hi " + friend + ".  Please come to my party on Saturday!"
    print(invitation)
    
print ("\nExmaple 2")
for x in range(13):   # Generate numbers 0 to 12
    print(x, '\t', 2**x)
# Out:
# Exmaple 1
# Hi Margot.  Please come to my party on Saturday!
# Hi Kathryn.  Please come to my party on Saturday!
# Hi Prisila.  Please come to my party on Saturday!
#
# Exmaple 2
# 0 	 1
# 1 	 2
# 2 	 4
# 3 	 8
# 4 	 16
# 5 	 32
# 6 	 64
# 7 	 128
# 8 	 256
# 9 	 512
# 10 	 1024
# 11 	 2048
# 12 	 4096

# %% [markdown]
# ### While

# %%
number = 0
prompt = "Type any integer value, and type 42 to stop this...: "

while int(number) != 42:
    number =  input(prompt)
# Out:
# Type any integer value, and type 42 to stop this...: 42

# %% [markdown]
# ### Conditional Statement

# %%
x = 1
y = 2

if x < y:
    print ("x:" + str(x) + " is less than y:" + str(y))
elif x > y:
    print ("x:" + str(x) + " is greater than y:" + str(y))
else:
    print ("x:" + str(x) + " equals y:" + str(y))

# %% [markdown]
# ### Exception Handling

# %% [markdown]
# #### Bad

# %%
res = 10 * (1/0)

# %% [markdown]
# #### Handling Exceptions

# %%
try:
    res = 10 * (1/0)
except ZeroDivisionError as zeroDivisionError:
    print("ZeroDivisionError is caugth - ex message: " + str(zeroDivisionError))

print("--------------")
    
try:
    raise NameError('HiThere')
except ZeroDivisionError as zeroDivisionError:
    print("ZeroDivisionError is caugth - ex message: " + str(zeroDivisionError))
except NameError as nameError:
     print("NameError is caugth - ex message: " + str(nameError))

print("--------------")
try:
    raise Exception('HiThere again')
except ZeroDivisionError as zeroDivisionError:
    print("ZeroDivisionError is caugth - ex message: " + str(zeroDivisionError))
except NameError as nameError:
     print("NameError is caugth - ex message: " + str(nameError))
except Exception as exception:
     print("Exception is caugth - ex message: " + str(exception))

# %% [markdown]
# ##### Exercise 1
# a) Instantiate a variable and set it to 100.
# b) Write a statement to allow the user to enter an integer value, named y.
# c) When x is stricly greater than y then print to the user that "x is stricly greater than y", otherwise print "x is less or equal to y", also indicate the value of x and y.
#
# Tip: Ensure you catch exception, as the user may enter a value that is not an integer in the input window which will break the code.
#
# Good Luck!

# %% [markdown]
# ##### Solution to exercise 1

# %%
try:
    x = 100

    y = int(input("Please enter the value of y: "))

    if x > y:
        print ("x: " + str(x) + " is strictly greater than y: " + str(y))
    else:
        print ("x: " + str(x) + " is less or equal to than y: " + str(y))

except Exception as exception:
     print("Exception is caugth - ex message: " + str(exception))
# Out:
# Please enter the value of y: 100
# x: 100 is less or equal to than y: 100

# %% [markdown]
# ## 1. Introduction To Pandas

# %%
print("*** Create a series:")
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# *** Create a series:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
print("*** Create a dataframe:")
dates = pd.date_range('20130101', periods=12)
df = pd.DataFrame(np.random.randn(len(dates),4),index=dates, columns=list('ABCD'))
df
# Out:
# *** Create a dataframe:
#                    A         B         C         D
# 2013-01-01 -0.066923 -0.618888 -0.890960  0.218905
# 2013-01-02  2.371766 -0.441658 -0.968038  0.778081
# 2013-01-03  0.010270  0.823157  2.204060  1.799568
# 2013-01-04  1.293636  1.771026  0.657272 -0.643907
# 2013-01-05 -1.373060  2.011173 -1.616743 -0.635114
# 2013-01-06 -1.384931 -0.456901 -0.155376 -0.817087
# 2013-01-07 -0.957119  1.209350  0.085343  1.404599
# 2013-01-08  0.696119  0.789924 -1.176783 -2.604210
# 2013-01-09  2.889326  1.732652 -0.678259  0.384875
# 2013-01-10 -0.064868 -0.774195  2.249395  2.085500
# 2013-01-11  0.912510 -0.474577 -0.845673  0.023511
# 2013-01-12  0.833201  0.348805  0.149739  0.144498

# %%
print("*** Create a dataframe  containing heterogeneous data:")
df2 = pd.DataFrame({ 'A' : 1.,
                     'B' : pd.Timestamp('20130102'),
                     'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                     'D' : np.array([3] * 4,dtype='int32'),
                     'E' : pd.Categorical(["test","train","test","train"]),
                     'F' : 'foo' })
print(df2)
# Out:
# *** Create a dataframe  containing heterogeneous data:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
print("*** Get Type and column names")
df2.dtypes
# Out:
# *** Get Type and column names
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
print("*** Viewing Data\n")
print("head")
print(df.head())
print("\ntail")
print(df.tail(2))
# Out:
# *** Viewing Data
#
# head
#                    A         B         C         D
# 2013-01-01 -0.066923 -0.618888 -0.890960  0.218905
# 2013-01-02  2.371766 -0.441658 -0.968038  0.778081
# 2013-01-03  0.010270  0.823157  2.204060  1.799568
# 2013-01-04  1.293636  1.771026  0.657272 -0.643907
# 2013-01-05 -1.373060  2.011173 -1.616743 -0.635114
#
# tail
#                    A         B         C         D
# 2013-01-11  0.912510 -0.474577 -0.845673  0.023511
# 2013-01-12  0.833201  0.348805  0.149739  0.144498

# %%
print("*** Display the index, columns, and the underlying data:")
display(df.index)
display(df.columns)
display(df.values)
# Out:
# *** Display the index, columns, and the underlying data:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12'],
#               dtype='datetime64[ns]', freq='D')
# Index(['A', 'B', 'C', 'D'], dtype='object')
# array([[-0.06692281, -0.61888828, -0.89096021,  0.21890453],
#        [ 2.37176646, -0.44165841, -0.96803761,  0.77808128],
#        [ 0.01027006,  0.82315748,  2.2040603 ,  1.79956796],
#        [ 1.29363612,  1.7710257 ,  0.6572716 , -0.64390697],
#        [-1.37305967,  2.01117298, -1.61674262, -0.63511418],
#        [-1.38493135, -0.45690113, -0.15537602, -0.81708743],
#        [-0.95711931,  1.20934976,  0.08534276,  1.40459907],
#        [ 0.69611874,  0.78992387, -1.17678277, -2.60421026],
#        [ 2.88932554,  1.73265234, -0.67825865,  0.38487466],
# ...

# %%
print("*** Sorting Data:\n")
print("No Sorting:")
display(df)
print("Sorting by Row Index:")
display(df.sort_index(axis=0, ascending=False))
print("Sorting by Col Names:")
display(df.sort_index(axis=1, ascending=False))
print("Sorting by Specific Col Names:")
df.sort_values(by='A', ascending=False)
# Out:
# *** Sorting Data:
#
# No Sorting:
#                    A         B         C         D
# 2013-01-01 -0.066923 -0.618888 -0.890960  0.218905
# 2013-01-02  2.371766 -0.441658 -0.968038  0.778081
# 2013-01-03  0.010270  0.823157  2.204060  1.799568
# 2013-01-04  1.293636  1.771026  0.657272 -0.643907
# 2013-01-05 -1.373060  2.011173 -1.616743 -0.635114
# 2013-01-06 -1.384931 -0.456901 -0.155376 -0.817087
# 2013-01-07 -0.957119  1.209350  0.085343  1.404599
# 2013-01-08  0.696119  0.789924 -1.176783 -2.604210
# 2013-01-09  2.889326  1.732652 -0.678259  0.384875
# 2013-01-10 -0.064868 -0.774195  2.249395  2.085500
# 2013-01-11  0.912510 -0.474577 -0.845673  0.023511
# 2013-01-12  0.833201  0.348805  0.149739  0.144498
# Sorting by Row Index:
#                    A         B         C         D
# 2013-01-12  0.833201  0.348805  0.149739  0.144498
# 2013-01-11  0.912510 -0.474577 -0.845673  0.023511
# 2013-01-10 -0.064868 -0.774195  2.249395  2.085500
# ...

# %%
print("*** Grouping Data:\n")
print("No Grouping:")
display(df2)
print("No Grouping By col A and sum vertically:")
display(df2.groupby('A').sum())
print("No Grouping By col B and avg vertically:")
display(df2.groupby('B').mean())

print("No Grouping By col A and E and then sum vertically:")
display(df2.groupby(['A', 'E']).sum())
# Out:
# *** Grouping Data:
#
# No Grouping:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# No Grouping By col A and sum vertically:
#        C   D
# A
# 1.0  4.0  12
# No Grouping By col B and avg vertically:
#               A    C  D
# B
# 2013-01-02  1.0  1.0  3
# No Grouping By col A and E and then sum vertically:
#              C  D
# A   E
# 1.0 test   2.0  6
#     train  2.0  6

# %% [markdown]
# ##### Exercise 2
# 1. Create a panda dataframe_1 that contains 5 rows and 2 columns. Column one is named 'Date' and column 2 is name 'Amount'.
# 2. Choose your dates and amounts and the load the rows in the dataframe.
# 3. Generate dataframe_2 that sorts the dataframe_1 'Amount' column in descending order.
# 4. Generate dataframe_3 that groups the dataframe_1 by the 'Date' and sum by 'Amount'.
#
# Good luck!

# %% [markdown]
# ##### Solution to exercise 2

# %%
dataframe_1 = pd.DataFrame({ 'Date' :pd.Timestamp('20130102'),
                             'Amount' : np.array([1000.0, 2000.5, 5000, 5000, 1000  ],dtype='float')})
display(dataframe_1)

dataframe_2 = dataframe_1.sort_values(by='Amount', ascending=False)
display(dataframe_2)

dataframe_3 = dataframe_1.groupby(['Date']).sum()
display(dataframe_3)
# Out:
#    Amount       Date
# 0  1000.0 2013-01-02
# 1  2000.5 2013-01-02
# 2  5000.0 2013-01-02
# 3  5000.0 2013-01-02
# 4  1000.0 2013-01-02
#    Amount       Date
# 2  5000.0 2013-01-02
# 3  5000.0 2013-01-02
# 1  2000.5 2013-01-02
# 0  1000.0 2013-01-02
# 4  1000.0 2013-01-02
#              Amount
# Date
# 2013-01-02  14000.5

# %% [markdown]
# # 2. Data Exploration

# %% [markdown]
# ## 2.1 Data Load

# %%
df_train = pd.read_csv("train.csv")
#import os
#print(os.getcwd())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## 2.2 Shared Functions

# %%
def get_num_cols(data):
    return data.select_dtypes(include=[np.number])

def get_cat_cols(data):
    return data.select_dtypes(exclude=[np.number])

def get_col_names(data):
    return list(data.columns.values);

def get_num_data_and_schema(data):
    num_data = get_num_cols(data)
    num_data = num_data.dropna()
    num_col_headers = get_col_names(num_data)
    return num_col_headers, num_data

def set_default_plt_display(x=20, y=80, col_number=3):
    plt.figure(figsize=(x, y))
    gs = gridspec.GridSpec(x, col_number)
    sbn.set_style("darkgrid", {'grid.color': '.8', 'ytick.color': '.15'})
    return gs

#def generate_histogram_cat(names, values, item, width, length):
#    fig, axs = plt.subplots(figsize=(width, length))
#    axs.bar(names, values)
#    fig.suptitle(item)
#    plt.show()

# %% [markdown]
# ## 2.3 Data Analysis

# %% [markdown]
# ### First 10 records

# %%
display(df_train.head(10))
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5  1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6  1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7  1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8  1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9  1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# ...

# %% [markdown]
# ### Data Shape

# %%
print("[rows X cols] -> {} X {}".format(df_train.shape[0], len(df_train.columns)))
# Out:
# [rows X cols] -> 1459 X 80

# %% [markdown]
# ### Data Types

# %%
display(df_train.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# ...

# %% [markdown]
# ### Describe (excl missing data)

# %%
num_col_headers, num_data = get_num_data_and_schema(df_train)
display(num_data.dropna().describe())
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1146.000000  1146.000000  1146.000000   1146.000000  1146.000000
# mean   2187.336824    56.461606    69.020942   9560.188482     6.138743
# std     423.997893    42.486338    22.381712   4422.310277     1.458880
# min    1461.000000    20.000000    21.000000   1484.000000     1.000000
# 25%    1817.250000    20.000000    59.000000   7200.000000     5.000000
# 50%    2198.500000    50.000000    68.000000   9350.000000     6.000000
# 75%    2545.750000    70.000000    80.000000  11220.750000     7.000000
# max    2919.000000   190.000000   200.000000  51974.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1146.000000  1146.000000   1146.000000  1146.000000  1146.000000
# mean      5.589005  1971.695462   1984.129145   102.821117   439.190227
# std       1.066120    30.683263     21.321308   178.843305   464.159629
# ...

# %% [markdown]
# ### Extra Statistics

# %%
def statistics(data):
    for index, item in enumerate(data):
        print("Name: %s" % item + " - Skewness: %f" % data[item].skew() + " - Kurtosis: %f" % data[item].kurt())

statistics(num_data)
# Out:
# Name: Id - Skewness: -0.001520 - Kurtosis: -1.205581
# Name: MSSubClass - Skewness: 1.358427 - Kurtosis: 1.315957
# Name: LotFrontage - Skewness: 0.689611 - Kurtosis: 2.716086
# Name: LotArea - Skewness: 2.445602 - Kurtosis: 16.126112
# Name: OverallQual - Skewness: 0.194311 - Kurtosis: 0.047143
# Name: OverallCond - Skewness: 0.711304 - Kurtosis: 1.338048
# Name: YearBuilt - Skewness: -0.560095 - Kurtosis: -0.654840
# Name: YearRemodAdd - Skewness: -0.430999 - Kurtosis: -1.399653
# Name: MasVnrArea - Skewness: 2.454933 - Kurtosis: 7.899424
# Name: BsmtFinSF1 - Skewness: 1.284161 - Kurtosis: 3.255738
# Name: BsmtFinSF2 - Skewness: 3.842443 - Kurtosis: 15.600109
# Name: BsmtUnfSF - Skewness: 0.915689 - Kurtosis: 0.307545
# Name: TotalBsmtSF - Skewness: 1.007508 - Kurtosis: 5.996072
# Name: 1stFlrSF - Skewness: 1.559162 - Kurtosis: 8.095302
# Name: 2ndFlrSF - Skewness: 0.895500 - Kurtosis: -0.305595
# Name: LowQualFinSF - Skewness: 16.961251 - Kurtosis: 333.469914
# ...

# %% [markdown]
# #### Exercise 3
# 1. Load the test.csv
# 2. List the datatype of each column
# 3. Get the first 5 rows
# 4. Use the 'Describe' function to get insight on data

# %% [markdown]
# #### Solution to Exercise 3

# %%
print("1.Load the test.csv")
df_test = pd.read_csv("test.csv")
print("2.List the datatype of each column")
display(df_test.dtypes)
print("3.Get the first 5 rows")
display(df_test.head(5))
print("4.Data Insight")
num_col_headers, num_data = get_num_data_and_schema(df_test)
display(num_data.dropna().describe())
# Out:
# 1.Load the test.csv
# 2.List the datatype of each column
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# ...

# %% [markdown]
# ## 2.4 Category Description

# %%
def describe_cat(data):
    cat_columns = data.select_dtypes(exclude=[np.number]).columns
    for index, item in enumerate(cat_columns):
        count = data.groupby(item)[item].count()
        res = pd.concat([count], axis=1, keys=['Count']).sort_values(['Count'], ascending=[0])
        display(res)
        
describe_cat(df_train)
# Out:
#           Count
# MSZoning
# RL         1114
# RM          242
# FV           74
# C (all)      15
# RH           10
#         Count
# Street
# Pave     1453
# Grvl        6
#        Count
# Alley
# Grvl      70
# Pave      37
#           Count
# LotShape
# Reg         934
# IR1         484
# IR2          35
# IR3           6
#              Count
# LandContour
# Lvl           1311
# HLS             70
# Bnk             54
# Low             24
#            Count
# Utilities
# AllPub      1457
#            Count
# LotConfig
# Inside      1081
# Corner       248
# CulDSac       82
# FR2           38
# FR3           10
#            Count
# LandSlope
# Gtl         1396
# Mod           60
# Sev            3
#               Count
# Neighborhood
# NAmes           218
# OldTown         126
# CollgCr         117
# Somerst          96
# Edwards          94
# NridgHt          89
# Gilbert          86
# Sawyer           77
# SawyerW          66
# Mitchel          65
# NWAmes           58
# ...

# %%
def generate_histograms_cat(data, width=30, length=10):
    cat_columns = data.select_dtypes(exclude=[np.number]).columns
    for index, item in enumerate(cat_columns):
        count = data.groupby(item)[item].count()
        res = pd.concat([count], axis=1, keys=['Count']).sort_values(['Count'], ascending=[0])
        names = res.transpose().columns.values.tolist()
        values = np.hstack(res.values).tolist()
        generate_histogram_cat(names, values, item, width, length)


        generate_histograms_cat(df_train, 20,5)

# %% [markdown]
# ## 2.5 Missing Data

# %%
def set_default_plt_display(x=20, y=80, col_number=3):
    plt.figure(figsize=(x, y))
    gs = gridspec.GridSpec(x, col_number)
    sbn.set_style("darkgrid", {'grid.color': '.8', 'ytick.color': '.15'})
    return gs

def missing_data_values(data):
    missing = data.isnull().sum().sort_values(ascending=False)
    total = data.isnull().count().sort_values(ascending=False)
    percent = missing / total
    missing_data = pd.concat([missing, total, percent], axis=1, keys=['Missing', 'Total', 'Percent'])
    return missing_data.sort_values(['Percent'], ascending=[0])

def missing_data_plot(grid_spec, data, missing_data_threshold=0.6):
    missing_data = missing_data_values(data)
    missing_data_perc = missing_data['Percent']
    ax = missing_data_perc.plot(
        kind='bar',
        color=['#AA0000' if perc > missing_data_threshold else '#000088' for perc in missing_data_perc], )
    plt.show()

gs = set_default_plt_display(20, 5,3)
missing_data_plot(gs, df_train)

# %% [markdown]
# ## 2.6 Box Plots

# %%
def generate_box_plot(grid_spec, index, data, column_name):
    x = pd.Series(data[column_name], name=column_name)
    sbn.boxplot(x).set_title(column_name)
    plt.subplot(grid_spec[index])

def generate_box_plots(grid_spec, data):
    num_col_headers, num_data = get_num_data_and_schema(data)
    for index, item in enumerate(num_col_headers):
        generate_box_plot(grid_spec, index, num_data, item)
        
set_default_plt_display(20, 120,3)
generate_box_plots(gs, df_train)

# %% [markdown]
# ## 2.7 Histograms

# %%
def generate_histogram(grid_spec, index, data, column_name):
    x = pd.Series(data[column_name], name=column_name)
    ax = sbn.distplot(x, color="r")
    plt.subplot(grid_spec[index])

def generate_histograms(grid_spec, data):
    num_col_headers, num_data = get_num_data_and_schema(data)
    for index, item in enumerate(num_col_headers):
        generate_histogram(grid_spec, index, num_data, item)

gs = set_default_plt_display(20, 120,3)
generate_histograms(gs, df_train)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## 2.8 Correlograms

# %%
def generate_correlogram(data, size_inches=10):
    num_col_headers, num_data = get_num_data_and_schema(data)
    correlations = num_data.corr()
    # plot correlation matrix
    fig = plt.figure()
    fig.set_size_inches(size_inches,size_inches)
    ax = fig.add_subplot(111)
    cax = ax.matshow(correlations, vmin=-1, vmax=1,cmap=cm.coolwarm)
    fig.colorbar(cax)
    fig.patch.set_facecolor('white')
    ticks = np.arange(0, len(num_data.columns), 1)
    ax.set_xticks(ticks)
    ax.set_yticks(ticks)
    ax.set_xticklabels(num_col_headers, rotation=45)
    ax.set_yticklabels(num_col_headers)
    plt.show()
    
generate_correlogram(df_train,20)

# %% [markdown]
# ## 2.9 Scatter Plots

# %%
def generate_scatter_plots(data, size_inches=10):
    num_col_headers, num_data = get_num_data_and_schema(data)
    pd.plotting.scatter_matrix(num_data,  figsize=(size_inches, size_inches))
    plt.show()  

generate_scatter_plots(df_train,20)

# %% [markdown]
# #### Excercise 4
# Use the test.csv data
# 1. Find the missing data where the ratio of missing data is greater than 10%
# 2. Draw a histogram for the data
# 3. Draw the correlogram
#
# Tips: Please feel free to reuse any of the custom functions provided above

# %% [markdown]
# #### Solution to Excercise 4

# %%
df_test = pd.read_csv("test.csv")

print("1.Find the missing data where the ratio of missing data is greater than 10%")
gs = set_default_plt_display(20, 5,3)
missing_data_plot(gs, df_test,missing_data_threshold=0.1)

print("2.Draw a histogram for the data")
gs = set_default_plt_display(20, 120,3)
generate_histograms(gs, df_test)

print("3.Draw the correlogram ")
generate_correlogram(df_test,20)
# Out:
# 1.Find the missing data where the ratio of missing data is greater than 10%
# 2.Draw a histogram for the data
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 3.Draw the correlogram

# %% [markdown]
# ### 2.10 Maps

# %%
# adress: "175 5th Avenue NYC"
def get_location_full_details(address):
    geolocator = Nominatim()
    location = geolocator.geocode(address)
    return location.raw

def get_location_long_lat(address):
    geolocator = Nominatim()
    location = geolocator.geocode(address)
    return location.latitude, location.longitude

def create_map_data(addresses, cities, values):
    lats = list()
    longs = list()

    for i in range(0, len(addresses)):
        address = addresses[i]
        long, lat = get_location_long_lat(address)
        lats.append(lat)
        longs.append(long)

    data = pd.DataFrame({
        'lat': lats,
        'lon': longs,
        'name': cities,
        'value': values
    })
    return data

def get_map(data, tiles="Mapbox Bright", zoom_start=9):
    # Make an empty map
    avg_location = [data['lon'].mean(), data['lat'].mean()]
    m = folium.Map(location=avg_location, tiles=tiles, zoom_start=zoom_start)
    return m

def get_map_marker(data, tiles="Mapbox Bright", zoom_start=9):
    m = get_map(data, tiles, zoom_start)
    # I can add marker one by one on the map
    for i in range(0, len(data)):
        folium.Marker(location=[data.iloc[i]['lon'], data.iloc[i]['lat']], popup=data.iloc[i]['name']).add_to(m)
    return m

def get_map_circle(data, tiles="Mapbox Bright", zoom_start=9, factor = 1):
    m = get_map(data, tiles, zoom_start)
    # I can add marker one by one on the map
    for i in range(0, len(data)):
        folium.Circle(location= [data.iloc[i]['lon'], data.iloc[i]['lat']],
                      popup=data.iloc[i]['name'], radius=float(data.iloc[i]['value']) * factor,
                      color='crimson', fill=True, fill_color='crimson').add_to(m)
    return m

addresses = ["18 Taunton Road London", "1 Cabot Square London", "2 Triton Square London"]
cities = ["London", "London", "London"]
values = ['100', '5', '50']
data = create_map_data(addresses, cities, values)

#get_map_marker(data,tiles="Mapbox Bright", zoom_start=9)
get_map_circle(data,tiles="Mapbox Bright", zoom_start=9, factor=20)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
