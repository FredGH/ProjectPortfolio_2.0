# %% [markdown]
# ## Set Lib Path

# %% [markdown]
# ## Import Libraries

# %%
from IPython.display import display
import numpy as np
import pandas as pd
import seaborn as sbn
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from geopy.geocoders import Nominatim
import folium

#Show graph in line
# %matplotlib inline 

print ("All dependent libs have been loaded.")
# Out:
# All dependent libs have been loaded.

# %% [markdown]
# ## Hello World

# %%
print ("hello world")
# Out:
# hello world

# %% [markdown]
# ## 0. Basic Concepts

# %% [markdown]
# ### For loops

# %%
print ("Exmaple 1")
for friend in ['Margot', 'Kathryn', 'Prisila']:
    invitation = "Hi " + friend + ".  Please come to my party on Saturday!"
    print(invitation)
    
print ("\nExmaple 2")
for x in range(13):   # Generate numbers 0 to 12
    print(x, '\t', 2**x)
# Out:
# Exmaple 1
# Hi Margot.  Please come to my party on Saturday!
# Hi Kathryn.  Please come to my party on Saturday!
# Hi Prisila.  Please come to my party on Saturday!
#
# Exmaple 2
# 0 	 1
# 1 	 2
# 2 	 4
# 3 	 8
# 4 	 16
# 5 	 32
# 6 	 64
# 7 	 128
# 8 	 256
# 9 	 512
# 10 	 1024
# 11 	 2048
# 12 	 4096

# %% [markdown]
# ### While

# %%
number = 0
prompt = "Type any integer value, and type 42 to stop this...: "

while int(number) != 42:
    number =  input(prompt)
# Out:
# Type any integer value, and type 42 to stop this...: 42

# %% [markdown]
# ### Conditional Statement

# %%
x = 1
y = 2

if x < y:
    print ("x:" + str(x) + " is less than y:" + str(y))
elif x > y:
    print ("x:" + str(x) + " is greater than y:" + str(y))
else:
    print ("x:" + str(x) + " equals y:" + str(y))
# Out:
# x:1 is less than y:2

# %% [markdown]
# ### Data Structures

# %%
## List (see for the info: http://thomas-cokelaer.info/tutorials/python/lists.html)
print("List")
l = [1, 2, 3]
display(l)
print("l.append(1)")
l.append(1)
display(l)
print("l.append(['d', 'e', 'f'])")
l.append(['d', 'e', 'f'])
display(l)
print("l.extend(['d', 'e', 'f'])")
l.extend(['d', 'e', 'f'])
display(l)

# For the other data structures, please see http://thomas-cokelaer.info/tutorials/python/data_structures.html
# Out:
# List
# [1, 2, 3]
# l.append(1)
# [1, 2, 3, 1]
# l.append(['d', 'e', 'f'])
# [1, 2, 3, 1, ['d', 'e', 'f']]
# l.extend(['d', 'e', 'f'])
# [1, 2, 3, 1, ['d', 'e', 'f'], 'd', 'e', 'f']

# %% [markdown]
# ### Exception Handling

# %% [markdown]
# #### Bad

# %%
res = 10 * (1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-8c83ab277ad7> in <module>()
# ----> 1 res = 10 * (1/0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# #### Handling Exceptions

# %%
try:
    res = 10 * (1/0)
except ZeroDivisionError as zeroDivisionError:
    print("ZeroDivisionError is caugth - ex message: " + str(zeroDivisionError))

print("--------------")
    
try:
    raise NameError('HiThere')
except ZeroDivisionError as zeroDivisionError:
    print("ZeroDivisionError is caugth - ex message: " + str(zeroDivisionError))
except NameError as nameError:
     print("NameError is caugth - ex message: " + str(nameError))

print("--------------")
try:
    raise Exception('HiThere again')
except ZeroDivisionError as zeroDivisionError:
    print("ZeroDivisionError is caugth - ex message: " + str(zeroDivisionError))
except NameError as nameError:
     print("NameError is caugth - ex message: " + str(nameError))
except Exception as exception:
     print("Exception is caugth - ex message: " + str(exception))
# Out:
# ZeroDivisionError is caugth - ex message: division by zero
# --------------
# NameError is caugth - ex message: HiThere
# --------------
# Exception is caugth - ex message: HiThere again

# %% [markdown]
# ##### Exercise 1
# a) Instantiate a variable and set it to 100.
# b) Write a statement to allow the user to enter an integer value, named y.
# c) When x is stricly greater than y then print to the user that "x is stricly greater than y", otherwise print "x is less or equal to y", also indicate the value of x and y.
#
# Tip: Ensure you catch exception, as the user may enter a value that is not an integer in the input window which will break the code.
#
# Good Luck!

# %% [markdown]
# ##### Solution to exercise 1

# %% [markdown]
# ## 1. Introduction To Pandas

# %%
print("*** Create a series:")
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# *** Create a series:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
print("*** Create a dataframe:")
dates = pd.date_range('20130101', periods=12)
df = pd.DataFrame(np.random.randn(len(dates),4),index=dates, columns=list('ABCD'))
df
# Out:
# *** Create a dataframe:
#                    A         B         C         D
# 2013-01-01  1.853745 -0.370554  0.066157  2.217072
# 2013-01-02  1.674243 -1.506467 -0.914982 -1.507337
# 2013-01-03  0.534309  0.406318 -0.055853  0.698644
# 2013-01-04  0.392189  0.456518 -0.518251  0.044706
# 2013-01-05  0.538823 -0.114595 -0.429731  1.101346
# 2013-01-06 -0.578593  0.496870  0.045373  0.586010
# 2013-01-07 -0.724745 -0.055717  0.946016 -0.416303
# 2013-01-08  0.672611  0.205965 -2.439093 -0.410124
# 2013-01-09  2.062023 -0.056411 -0.618231 -2.342056
# 2013-01-10 -1.896117 -2.087907  0.070244  0.621183
# 2013-01-11  0.038527 -0.009884 -0.254125  1.619529
# 2013-01-12 -1.043976 -0.909232 -1.109296  0.398642

# %%
print("*** Create a dataframe  containing heterogeneous data:")
df2 = pd.DataFrame({ 'A' : 1.,
                     'B' : pd.Timestamp('20130102'),
                     'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                     'D' : np.array([3] * 4,dtype='int32'),
                     'E' : pd.Categorical(["test","train","test","train"]),
                     'F' : 'foo' })
print(df2)
# Out:
# *** Create a dataframe  containing heterogeneous data:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
print("*** Get Type and column names")
df2.dtypes
# Out:
# *** Get Type and column names
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
print("*** Viewing Data\n")
print("head")
print(df.head())
print("\ntail")
print(df.tail(2))
# Out:
# *** Viewing Data
#
# head
#                    A         B         C         D
# 2013-01-01  1.853745 -0.370554  0.066157  2.217072
# 2013-01-02  1.674243 -1.506467 -0.914982 -1.507337
# 2013-01-03  0.534309  0.406318 -0.055853  0.698644
# 2013-01-04  0.392189  0.456518 -0.518251  0.044706
# 2013-01-05  0.538823 -0.114595 -0.429731  1.101346
#
# tail
#                    A         B         C         D
# 2013-01-11  0.038527 -0.009884 -0.254125  1.619529
# 2013-01-12 -1.043976 -0.909232 -1.109296  0.398642

# %%
print("*** Display the index, columns, and the underlying data:")
display(df.index)
display(df.columns)
display(df.values)
# Out:
# *** Display the index, columns, and the underlying data:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12'],
#               dtype='datetime64[ns]', freq='D')
# Index(['A', 'B', 'C', 'D'], dtype='object')
# array([[ 1.85374452, -0.37055398,  0.06615715,  2.21707165],
#        [ 1.67424323, -1.50646742, -0.91498173, -1.50733725],
#        [ 0.53430871,  0.40631757, -0.05585282,  0.69864372],
#        [ 0.3921889 ,  0.45651751, -0.51825108,  0.04470577],
#        [ 0.53882272, -0.11459536, -0.42973119,  1.10134606],
#        [-0.57859256,  0.49686967,  0.0453731 ,  0.58601033],
#        [-0.72474483, -0.05571718,  0.94601631, -0.41630326],
#        [ 0.67261117,  0.20596458, -2.4390928 , -0.41012434],
#        [ 2.0620233 , -0.05641087, -0.6182312 , -2.34205554],
#        [-1.89611727, -2.08790705,  0.07024399,  0.62118303],
#        [ 0.03852718, -0.00988423, -0.2541252 ,  1.61952861],
#        [-1.04397577, -0.90923155, -1.10929601,  0.3986424 ]])

# %%
print("*** Sorting Data:\n")
print("No Sorting:")
display(df)
print("Sorting by Row Index:")
display(df.sort_index(axis=0, ascending=False))
print("Sorting by Col Names:")
display(df.sort_index(axis=1, ascending=False))
print("Sorting by Specific Col Names:")
df.sort_values(by='A', ascending=False)
# Out:
# *** Sorting Data:
#
# No Sorting:
#                    A         B         C         D
# 2013-01-01  1.853745 -0.370554  0.066157  2.217072
# 2013-01-02  1.674243 -1.506467 -0.914982 -1.507337
# 2013-01-03  0.534309  0.406318 -0.055853  0.698644
# 2013-01-04  0.392189  0.456518 -0.518251  0.044706
# 2013-01-05  0.538823 -0.114595 -0.429731  1.101346
# 2013-01-06 -0.578593  0.496870  0.045373  0.586010
# 2013-01-07 -0.724745 -0.055717  0.946016 -0.416303
# 2013-01-08  0.672611  0.205965 -2.439093 -0.410124
# 2013-01-09  2.062023 -0.056411 -0.618231 -2.342056
# 2013-01-10 -1.896117 -2.087907  0.070244  0.621183
# 2013-01-11  0.038527 -0.009884 -0.254125  1.619529
# 2013-01-12 -1.043976 -0.909232 -1.109296  0.398642
# Sorting by Row Index:
#                    A         B         C         D
# 2013-01-12 -1.043976 -0.909232 -1.109296  0.398642
# 2013-01-11  0.038527 -0.009884 -0.254125  1.619529
# 2013-01-10 -1.896117 -2.087907  0.070244  0.621183
# 2013-01-09  2.062023 -0.056411 -0.618231 -2.342056
# 2013-01-08  0.672611  0.205965 -2.439093 -0.410124
# 2013-01-07 -0.724745 -0.055717  0.946016 -0.416303
# 2013-01-06 -0.578593  0.496870  0.045373  0.586010
# 2013-01-05  0.538823 -0.114595 -0.429731  1.101346
# 2013-01-04  0.392189  0.456518 -0.518251  0.044706
# 2013-01-03  0.534309  0.406318 -0.055853  0.698644
# 2013-01-02  1.674243 -1.506467 -0.914982 -1.507337
# 2013-01-01  1.853745 -0.370554  0.066157  2.217072
# Sorting by Col Names:
#                    D         C         B         A
# 2013-01-01  2.217072  0.066157 -0.370554  1.853745
# 2013-01-02 -1.507337 -0.914982 -1.506467  1.674243
# 2013-01-03  0.698644 -0.055853  0.406318  0.534309
# 2013-01-04  0.044706 -0.518251  0.456518  0.392189
# 2013-01-05  1.101346 -0.429731 -0.114595  0.538823
# 2013-01-06  0.586010  0.045373  0.496870 -0.578593
# 2013-01-07 -0.416303  0.946016 -0.055717 -0.724745
# 2013-01-08 -0.410124 -2.439093  0.205965  0.672611
# 2013-01-09 -2.342056 -0.618231 -0.056411  2.062023
# 2013-01-10  0.621183  0.070244 -2.087907 -1.896117
# 2013-01-11  1.619529 -0.254125 -0.009884  0.038527
# 2013-01-12  0.398642 -1.109296 -0.909232 -1.043976
# Sorting by Specific Col Names:
#                    A         B         C         D
# 2013-01-09  2.062023 -0.056411 -0.618231 -2.342056
# 2013-01-01  1.853745 -0.370554  0.066157  2.217072
# 2013-01-02  1.674243 -1.506467 -0.914982 -1.507337
# 2013-01-08  0.672611  0.205965 -2.439093 -0.410124
# 2013-01-05  0.538823 -0.114595 -0.429731  1.101346
# 2013-01-03  0.534309  0.406318 -0.055853  0.698644
# 2013-01-04  0.392189  0.456518 -0.518251  0.044706
# 2013-01-11  0.038527 -0.009884 -0.254125  1.619529
# 2013-01-06 -0.578593  0.496870  0.045373  0.586010
# 2013-01-07 -0.724745 -0.055717  0.946016 -0.416303
# 2013-01-12 -1.043976 -0.909232 -1.109296  0.398642
# 2013-01-10 -1.896117 -2.087907  0.070244  0.621183

# %%
print("*** Grouping Data:\n")
print("No Grouping:")
display(df2)
print("No Grouping By col A and sum vertically:")
display(df2.groupby('A').sum())
print("No Grouping By col B and avg vertically:")
display(df2.groupby('B').mean())

print("No Grouping By col A and E and then sum vertically:")
display(df2.groupby(['A', 'E']).sum())
# Out:
# *** Grouping Data:
#
# No Grouping:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# No Grouping By col A and sum vertically:
#        C   D
# A
# 1.0  4.0  12
# No Grouping By col B and avg vertically:
#               A    C  D
# B
# 2013-01-02  1.0  1.0  3
# No Grouping By col A and E and then sum vertically:
#              C  D
# A   E
# 1.0 test   2.0  6
#     train  2.0  6

# %% [markdown]
# ##### Exercise 2
# 1. Create a panda dataframe_1 that contains 5 rows and 2 columns. Column one is named 'Date' and column 2 is name 'Amount'.
# 2. Choose your dates and amounts and the load the rows in the dataframe.
# 3. Generate dataframe_2 that sorts the dataframe_1 'Amount' column in descending order.
# 4. Generate dataframe_3 that groups the dataframe_1 by the 'Date' and sum by 'Amount'.
#
# Good luck!

# %% [markdown]
# ##### Solution to exercise 2

# %% [markdown]
# # 2. Data Exploration

# %% [markdown]
# ## 2.1 Data Load

# %%
df_train = pd.read_csv("train.csv")
#import os
#print(os.getcwd())

# %% [markdown]
# ## 2.2 Shared Functions

# %%
def get_num_cols(data):
    return data.select_dtypes(include=[np.number])

def get_cat_cols(data):
    return data.select_dtypes(exclude=[np.number])

def get_col_names(data):
    return list(data.columns.values);

def get_num_data_and_schema(data):
    num_data = get_num_cols(data)
    num_data = num_data.dropna()
    num_col_headers = get_col_names(num_data)
    return num_col_headers, num_data

def set_default_plt_display(x=20, y=80, col_number=3):
    plt.figure(figsize=(x, y))
    gs = gridspec.GridSpec(x, col_number)
    sbn.set_style("darkgrid", {'grid.color': '.8', 'ytick.color': '.15'})
    return gs

#def generate_histogram_cat(names, values, item, width, length):
#    fig, axs = plt.subplots(figsize=(width, length))
#    axs.bar(names, values)
#    fig.suptitle(item)
#    plt.show()

# %% [markdown]
# ## 2.3 Data Analysis

# %% [markdown]
# ### First 10 records

# %%
display(df_train.head(10))
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 5         Lvl    AllPub    ...            0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 7         Lvl    AllPub    ...            0    NaN    NaN        Shed     350
# 8         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 9         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %% [markdown]
# ### Data Shape

# %%
print("[rows X cols] -> {} X {}".format(df_train.shape[0], len(df_train.columns)))
# Out:
# [rows X cols] -> 1460 X 81

# %% [markdown]
# ### Data Types

# %%
display(df_train.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# FireplaceQu       object
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# GarageQual        object
# GarageCond        object
# PavedDrive        object
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# PoolQC            object
# Fence             object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# ### Describe (excl missing data)

# %%
num_col_headers, num_data = get_num_data_and_schema(df_train)
display(num_data.dropna().describe())
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1121.000000  1121.000000  1121.000000    1121.000000  1121.000000
# mean    726.842105    56.146298    70.665477   10122.956289     6.212310
# std     420.769012    41.772684    24.266812    8129.302641     1.380822
# min       1.000000    20.000000    21.000000    1300.000000     2.000000
# 25%     364.000000    20.000000    60.000000    7590.000000     5.000000
# 50%     725.000000    50.000000    70.000000    9416.000000     6.000000
# 75%    1091.000000    70.000000    80.000000   11361.000000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1121.000000  1121.000000   1121.000000  1121.000000  1121.000000
# mean      5.561106  1972.264942   1985.683318   108.487957   438.399643
# std       1.068236    30.967730     21.025974   189.500966   468.385038
# min       2.000000  1880.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1953.000000   1966.000000     0.000000     0.000000
# 50%       5.000000  1974.000000   1995.000000     0.000000   374.000000
# 75%       6.000000  2003.000000   2005.000000   170.000000   702.000000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1121.000000  1121.000000    1121.000000  1121.000000
# mean       ...          92.610169    46.130241      21.844781     3.348796
# std        ...         121.868623    64.390029      61.282083    29.772540
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    27.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea      MiscVal       MoSold       YrSold  \
# count  1121.000000  1121.000000  1121.000000  1121.000000  1121.000000
# mean     16.100803     2.934880    23.429081     6.339875  2007.795718
# std      57.801829    40.222087   165.759816     2.687854     1.335043
# min       0.000000     0.000000     0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000     0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000     0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000     0.000000     8.000000  2009.000000
# max     480.000000   648.000000  2500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1121.000000
# mean   185506.152542
# std     82999.159004
# min     35311.000000
# 25%    131000.000000
# 50%    164900.000000
# 75%    219500.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# ### Extra Statistics

# %%
def statistics(data):
    for index, item in enumerate(data):
        print("Name: %s" % item + " - Skewness: %f" % data[item].skew() + " - Kurtosis: %f" % data[item].kurt())

statistics(num_data)
# Out:
# Name: Id - Skewness: 0.018663 - Kurtosis: -1.188781
# Name: MSSubClass - Skewness: 1.412907 - Kurtosis: 1.587462
# Name: LotFrontage - Skewness: 2.251197 - Kurtosis: 18.444451
# Name: LotArea - Skewness: 15.608113 - Kurtosis: 368.123845
# Name: OverallQual - Skewness: 0.287800 - Kurtosis: -0.146053
# Name: OverallCond - Skewness: 0.846451 - Kurtosis: 1.067691
# Name: YearBuilt - Skewness: -0.618350 - Kurtosis: -0.539469
# Name: YearRemodAdd - Skewness: -0.565757 - Kurtosis: -1.252004
# Name: MasVnrArea - Skewness: 2.706945 - Kurtosis: 10.201728
# Name: BsmtFinSF1 - Skewness: 1.934077 - Kurtosis: 13.218754
# Name: BsmtFinSF2 - Skewness: 4.399358 - Kurtosis: 21.896975
# Name: BsmtUnfSF - Skewness: 0.875774 - Kurtosis: 0.336929
# Name: TotalBsmtSF - Skewness: 1.754916 - Kurtosis: 15.323527
# Name: 1stFlrSF - Skewness: 1.363783 - Kurtosis: 6.344873
# Name: 2ndFlrSF - Skewness: 0.807411 - Kurtosis: -0.498926
# Name: LowQualFinSF - Skewness: 10.020823 - Kurtosis: 104.326922
# Name: GrLivArea - Skewness: 1.549961 - Kurtosis: 6.159908
# Name: BsmtFullBath - Skewness: 0.568804 - Kurtosis: -1.165653
# Name: BsmtHalfBath - Skewness: 4.107874 - Kurtosis: 16.051122
# Name: FullBath - Skewness: 0.015822 - Kurtosis: -0.843806
# Name: HalfBath - Skewness: 0.638178 - Kurtosis: -1.218611
# Name: BedroomAbvGr - Skewness: 0.074427 - Kurtosis: 1.326941
# Name: KitchenAbvGr - Skewness: 4.822542 - Kurtosis: 23.096005
# Name: TotRmsAbvGrd - Skewness: 0.723117 - Kurtosis: 0.723189
# Name: Fireplaces - Skewness: 0.643698 - Kurtosis: -0.142032
# Name: GarageYrBlt - Skewness: -0.641738 - Kurtosis: -0.557253
# Name: GarageCars - Skewness: 0.206017 - Kurtosis: -0.399091
# Name: GarageArea - Skewness: 0.733894 - Kurtosis: 0.830180
# Name: WoodDeckSF - Skewness: 1.549793 - Kurtosis: 3.382436
# Name: OpenPorchSF - Skewness: 2.403928 - Kurtosis: 9.060325
# Name: EnclosedPorch - Skewness: 3.173250 - Kurtosis: 11.398802
# Name: 3SsnPorch - Skewness: 10.854868 - Kurtosis: 136.625205
# Name: ScreenPorch - Skewness: 4.019111 - Kurtosis: 17.540877
# Name: PoolArea - Skewness: 13.783823 - Kurtosis: 190.344512
# Name: MiscVal - Skewness: 9.699989 - Kurtosis: 110.014916
# Name: MoSold - Skewness: 0.173039 - Kurtosis: -0.410993
# Name: YrSold - Skewness: 0.106730 - Kurtosis: -1.204900
# Name: SalePrice - Skewness: 1.933615 - Kurtosis: 6.433445

# %% [markdown]
# #### Exercise 3
# 1. Load the test.csv
# 2. List the datatype of each column
# 3. Get the first 5 rows
# 4. Use the 'Describe' function to get insight on data

# %% [markdown]
# #### Solution to Exercise 3

# %% [markdown]
# ## 2.4 Category Description

# %%
def describe_cat(data):
    cat_columns = data.select_dtypes(exclude=[np.number]).columns
    for index, item in enumerate(cat_columns):
        count = data.groupby(item)[item].count()
        res = pd.concat([count], axis=1, keys=['Count']).sort_values(['Count'], ascending=[0])
        display(res)
        
describe_cat(df_train)
# Out:
#           Count
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
#         Count
# Street
# Pave     1454
# Grvl        6
#        Count
# Alley
# Grvl      50
# Pave      41
#           Count
# LotShape
# Reg         925
# IR1         484
# IR2          41
# IR3          10
#              Count
# LandContour
# Lvl           1311
# Bnk             63
# HLS             50
# Low             36
#            Count
# Utilities
# AllPub      1459
# NoSeWa         1
#            Count
# LotConfig
# Inside      1052
# Corner       263
# CulDSac       94
# FR2           47
# FR3            4
#            Count
# LandSlope
# Gtl         1382
# Mod           65
# Sev           13
#               Count
# Neighborhood
# NAmes           225
# CollgCr         150
# OldTown         113
# Edwards         100
# Somerst          86
# Gilbert          79
# NridgHt          77
# Sawyer           74
# NWAmes           73
# SawyerW          59
# BrkSide          58
# Crawfor          51
# Mitchel          49
# NoRidge          41
# Timber           38
# IDOTRR           37
# ClearCr          28
# StoneBr          25
# SWISU            25
# Blmngtn          17
# MeadowV          17
# BrDale           16
# Veenker          11
# NPkVill           9
# Blueste           2
#             Count
# Condition1
# Norm         1260
# Feedr          81
# Artery         48
# RRAn           26
# PosN           19
# RRAe           11
# PosA            8
# RRNn            5
# RRNe            2
#             Count
# Condition2
# Norm         1445
# Feedr           6
# Artery          2
# PosN            2
# RRNn            2
# PosA            1
# RRAe            1
# RRAn            1
#           Count
# BldgType
# 1Fam       1220
# TwnhsE      114
# Duplex       52
# Twnhs        43
# 2fmCon       31
#             Count
# HouseStyle
# 1Story        726
# 2Story        445
# 1.5Fin        154
# SLvl           65
# SFoyer         37
# 1.5Unf         14
# 2.5Unf         11
# 2.5Fin          8
#            Count
# RoofStyle
# Gable       1141
# Hip          286
# Flat          13
# Gambrel       11
# Mansard        7
# Shed           2
#           Count
# RoofMatl
# CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# ClyTile       1
# Membran       1
# Metal         1
# Roll          1
#              Count
# Exterior1st
# VinylSd        515
# HdBoard        222
# MetalSd        220
# Wd Sdng        206
# Plywood        108
# CemntBd         61
# BrkFace         50
# WdShing         26
# Stucco          25
# AsbShng         20
# BrkComm          2
# Stone            2
# AsphShn          1
# CBlock           1
# ImStucc          1
#              Count
# Exterior2nd
# VinylSd        504
# MetalSd        214
# HdBoard        207
# Wd Sdng        197
# Plywood        142
# CmentBd         60
# Wd Shng         38
# Stucco          26
# BrkFace         25
# AsbShng         20
# ImStucc         10
# Brk Cmn          7
# Stone            5
# AsphShn          3
# CBlock           1
# Other            1
#             Count
# MasVnrType
# None          864
# BrkFace       445
# Stone         128
# BrkCmn         15
#            Count
# ExterQual
# TA           906
# Gd           488
# Ex            52
# Fa            14
#            Count
# ExterCond
# TA          1282
# Gd           146
# Fa            28
# Ex             3
# Po             1
#             Count
# Foundation
# PConc         647
# CBlock        634
# BrkTil        146
# Slab           24
# Stone           6
# Wood            3
#           Count
# BsmtQual
# TA          649
# Gd          618
# Ex          121
# Fa           35
#           Count
# BsmtCond
# TA         1311
# Gd           65
# Fa           45
# Po            2
#               Count
# BsmtExposure
# No              953
# Av              221
# Gd              134
# Mn              114
#               Count
# BsmtFinType1
# Unf             430
# GLQ             418
# ALQ             220
# BLQ             148
# Rec             133
# LwQ              74
#               Count
# BsmtFinType2
# Unf            1256
# Rec              54
# LwQ              46
# BLQ              33
# ALQ              19
# GLQ              14
#          Count
# Heating
# GasA      1428
# GasW        18
# Grav         7
# Wall         4
# OthW         2
# Floor        1
#            Count
# HeatingQC
# Ex           741
# TA           428
# Gd           241
# Fa            49
# Po             1
#             Count
# CentralAir
# Y            1365
# N              95
#             Count
# Electrical
# SBrkr        1334
# FuseA          94
# FuseF          27
# FuseP           3
# Mix             1
#              Count
# KitchenQual
# TA             735
# Gd             586
# Ex             100
# Fa              39
#             Count
# Functional
# Typ          1360
# Min2           34
# Min1           31
# Mod            15
# Maj1           14
# Maj2            5
# Sev             1
#              Count
# FireplaceQu
# Gd             380
# TA             313
# Fa              33
# Ex              24
# Po              20
#             Count
# GarageType
# Attchd        870
# Detchd        387
# BuiltIn        88
# Basment        19
# CarPort         9
# 2Types          6
#               Count
# GarageFinish
# Unf             605
# RFn             422
# Fin             352
#             Count
# GarageQual
# TA           1311
# Fa             48
# Gd             14
# Ex              3
# Po              3
#             Count
# GarageCond
# TA           1326
# Fa             35
# Gd              9
# Po              7
# Ex              2
#             Count
# PavedDrive
# Y            1340
# N              90
# P              30
#         Count
# PoolQC
# Gd          3
# Ex          2
# Fa          2
#        Count
# Fence
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
#              Count
# MiscFeature
# Shed            49
# Gar2             2
# Othr             2
# TenC             1
#           Count
# SaleType
# WD         1267
# New         122
# COD          43
# ConLD         9
# ConLI         5
# ConLw         5
# CWD           4
# Oth           3
# Con           2
#                Count
# SaleCondition
# Normal          1198
# Partial          125
# Abnorml          101
# Family            20
# Alloca            12
# AdjLand            4

# %%
def generate_histograms_cat(data, width=30, length=10):
    cat_columns = data.select_dtypes(exclude=[np.number]).columns
    for index, item in enumerate(cat_columns):
        count = data.groupby(item)[item].count()
        res = pd.concat([count], axis=1, keys=['Count']).sort_values(['Count'], ascending=[0])
        names = res.transpose().columns.values.tolist()
        values = np.hstack(res.values).tolist()
        generate_histogram_cat(names, values, item, width, length)


        generate_histograms_cat(df_train, 20,5)

# %% [markdown]
# ## 2.5 Missing Data

# %%
def set_default_plt_display(x=20, y=80, col_number=3):
    plt.figure(figsize=(x, y))
    gs = gridspec.GridSpec(x, col_number)
    sbn.set_style("darkgrid", {'grid.color': '.8', 'ytick.color': '.15'})
    return gs

def missing_data_values(data):
    missing = data.isnull().sum().sort_values(ascending=False)
    total = data.isnull().count().sort_values(ascending=False)
    percent = missing / total
    missing_data = pd.concat([missing, total, percent], axis=1, keys=['Missing', 'Total', 'Percent'])
    return missing_data.sort_values(['Percent'], ascending=[0])

def missing_data_plot(grid_spec, data, missing_data_threshold=0.6):
    missing_data = missing_data_values(data)
    missing_data_perc = missing_data['Percent']
    ax = missing_data_perc.plot(
        kind='bar',
        color=['#AA0000' if perc > missing_data_threshold else '#000088' for perc in missing_data_perc], )
    plt.show()

gs = set_default_plt_display(20, 5,3)
missing_data_plot(gs, df_train)

# %% [markdown]
# ## 2.6 Box Plots

# %%
def generate_box_plot(grid_spec, index, data, column_name):
    x = pd.Series(data[column_name], name=column_name)
    sbn.boxplot(x).set_title(column_name)
    plt.subplot(grid_spec[index])

def generate_box_plots(grid_spec, data):
    num_col_headers, num_data = get_num_data_and_schema(data)
    for index, item in enumerate(num_col_headers):
        generate_box_plot(grid_spec, index, num_data, item)
        
set_default_plt_display(20, 120,3)
generate_box_plots(gs, df_train)

# %% [markdown]
# ## 2.7 Histograms

# %%
def generate_histogram(grid_spec, index, data, column_name):
    x = pd.Series(data[column_name], name=column_name)
    ax = sbn.distplot(x, color="r")
    plt.subplot(grid_spec[index])

def generate_histograms(grid_spec, data):
    num_col_headers, num_data = get_num_data_and_schema(data)
    for index, item in enumerate(num_col_headers):
        generate_histogram(grid_spec, index, num_data, item)

gs = set_default_plt_display(20, 120,3)
generate_histograms(gs, df_train)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## 2.8 Correlograms

# %%
def generate_correlogram(data, size_inches=10):
    num_col_headers, num_data = get_num_data_and_schema(data)
    correlations = num_data.corr()
    # plot correlation matrix
    fig = plt.figure()
    fig.set_size_inches(size_inches,size_inches)
    ax = fig.add_subplot(111)
    cax = ax.matshow(correlations, vmin=-1, vmax=1,cmap=cm.coolwarm)
    fig.colorbar(cax)
    fig.patch.set_facecolor('white')
    ticks = np.arange(0, len(num_data.columns), 1)
    ax.set_xticks(ticks)
    ax.set_yticks(ticks)
    ax.set_xticklabels(num_col_headers, rotation=45)
    ax.set_yticklabels(num_col_headers)
    plt.show()
    
generate_correlogram(df_train,20)

# %% [markdown]
# ## 2.9 Scatter Plots

# %%
def generate_scatter_plots(data, size_inches=10):
    num_col_headers, num_data = get_num_data_and_schema(data)
    pd.plotting.scatter_matrix(num_data,  figsize=(size_inches, size_inches))
    plt.show()  

generate_scatter_plots(df_train,20)

# %% [markdown]
# #### Excercise 4
# Use the test.csv data
# 1. Find the missing data where the ratio of missing data is greater than 10%
# 2. Draw a histogram for the data
# 3. Draw the correlogram
#
# Tips: Please feel free to reuse any of the custom functions provided above

# %% [markdown]
# #### Solution to Excercise 4

# %% [markdown]
# ### 2.10 Maps

# %%
# adress: "175 5th Avenue NYC"
def get_location_full_details(address):
    geolocator = Nominatim()
    location = geolocator.geocode(address)
    return location.raw

def get_location_long_lat(address):
    geolocator = Nominatim()
    location = geolocator.geocode(address)
    return location.latitude, location.longitude

def create_map_data(addresses, cities, values):
    lats = list()
    longs = list()

    for i in range(0, len(addresses)):
        address = addresses[i]
        long, lat = get_location_long_lat(address)
        lats.append(lat)
        longs.append(long)

    data = pd.DataFrame({
        'lat': lats,
        'lon': longs,
        'name': cities,
        'value': values
    })
    return data

def get_map(data, tiles="Mapbox Bright", zoom_start=9):
    # Make an empty map
    avg_location = [data['lon'].mean(), data['lat'].mean()]
    m = folium.Map(location=avg_location, tiles=tiles, zoom_start=zoom_start)
    return m

def get_map_marker(data, tiles="Mapbox Bright", zoom_start=9):
    m = get_map(data, tiles, zoom_start)
    # I can add marker one by one on the map
    for i in range(0, len(data)):
        folium.Marker(location=[data.iloc[i]['lon'], data.iloc[i]['lat']], popup=data.iloc[i]['name']).add_to(m)
    return m

def get_map_circle(data, tiles="Mapbox Bright", zoom_start=9, factor = 1):
    m = get_map(data, tiles, zoom_start)
    # I can add marker one by one on the map
    for i in range(0, len(data)):
        folium.Circle(location= [data.iloc[i]['lon'], data.iloc[i]['lat']],
                      popup=data.iloc[i]['name'], radius=float(data.iloc[i]['value']) * factor,
                      color='crimson', fill=True, fill_color='crimson').add_to(m)
    return m

addresses = ["18 Taunton Road London", "1 Cabot Square London", "2 Triton Square London"]
cities = ["London", "London", "London"]
values = ['100', '5', '50']
data = create_map_data(addresses, cities, values)

#get_map_marker(data,tiles="Mapbox Bright", zoom_start=9)
get_map_circle(data,tiles="Mapbox Bright", zoom_start=9, factor=20)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
