# %%
import os

print("Current directory:")
initial_dir = "C:/Users/Fred/PycharmProjects/DataScience/" #os.getcwd()
print(initial_dir)
import pandas as pd

print("Change directory to import function from .pys")
new_dir = os.path.join(initial_dir,"src/visualization")
os.chdir(new_dir)
print(new_dir)
import utilities as viz_utils

# %matplotlib inline
# Out:
# Current directory:
# C:/Users/Fred/PycharmProjects/DataScience/
# Change directory to import function from .pys
# C:/Users/Fred/PycharmProjects/DataScience/src/visualization

# %%
os.chdir(initial_dir)
df_train = pd.read_csv("data/raw/sales/train.csv")


#.iloc[:,0:9] => get the first 10cols.

#missing data
#SMOTE=> class imbalance
#remove 0 variance cols
#remove cols with high inter/inter correlation



#viz_utils.missing_data_values(df_train)
#viz_utils.missing_data_plot(df_train)

#viz_utils.generate_scatter(df_train)

#viz_utils.pair_plot(gs, df_train)
#viz_utils.describe_cat(df_train)  


#do the freq graph => https://stackoverflow.com/questions/33179122/seaborn-countplot-with-frequencies
# Out:
# ******************
# *********
# index: 0, name: MSZoning
# *********
#           Count
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# *********
# ******************
# *********
# index: 1, name: Street
# *********
#         Count
# Street
# Pave     1454
# Grvl        6
# *********
# ******************
# *********
# index: 2, name: Alley
# *********
#        Count
# Alley
# Grvl      50
# Pave      41
# *********
# ******************
# *********
# index: 3, name: LotShape
# *********
#           Count
# LotShape
# Reg         925
# IR1         484
# IR2          41
# IR3          10
# *********
# ******************
# *********
# index: 4, name: LandContour
# *********
#              Count
# LandContour
# Lvl           1311
# Bnk             63
# HLS             50
# Low             36
# *********
# ******************
# *********
# index: 5, name: Utilities
# *********
#            Count
# Utilities
# AllPub      1459
# ...

# %%
viz_utils.describe_cat(df_train)
# Out:
# ******************
# *********
# index: 0, name: MSZoning
# *********
#           Count
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# *********
# ******************
# *********
# index: 1, name: Street
# *********
#         Count
# Street
# Pave     1454
# Grvl        6
# *********
# ******************
# *********
# index: 2, name: Alley
# *********
#        Count
# Alley
# Grvl      50
# Pave      41
# *********
# ******************
# *********
# index: 3, name: LotShape
# *********
#           Count
# LotShape
# Reg         925
# IR1         484
# IR2          41
# IR3          10
# *********
# ******************
# *********
# index: 4, name: LandContour
# *********
#              Count
# LandContour
# Lvl           1311
# Bnk             63
# HLS             50
# Low             36
# *********
# ******************
# *********
# index: 5, name: Utilities
# *********
#            Count
# Utilities
# AllPub      1459
# ...

# %%
gs = viz_utils.set_default_plt_display(20, 120,3)
viz_utils.generate_histograms_cat(gs,df_train)
# Out:
# ******************
# *********
# index: 0, name: MSZoning
# *********
#           Count
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# *********
# ******************
# *********
# index: 1, name: Street
# *********
#         Count
# Street
# Pave     1454
# Grvl        6
# *********
# ******************
# *********
# index: 2, name: Alley
# *********
#        Count
# Alley
# Grvl      50
# Pave      41
# *********
# ******************
# *********
# index: 3, name: LotShape
# *********
#           Count
# LotShape
# Reg         925
# IR1         484
# IR2          41
# IR3          10
# *********
# ******************
# *********
# index: 4, name: LandContour
# *********
#              Count
# LandContour
# Lvl           1311
# Bnk             63
# HLS             50
# Low             36
# *********
# ******************
# *********
# index: 5, name: Utilities
# *********
#            Count
# Utilities
# AllPub      1459
# ...

# %% [markdown]
# # Summary

# %%
viz_utils.summary(df_train)
# Out:
# First 10 records
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# # Missing Data

# %%
gs = viz_utils.set_default_plt_display(20, 5,3)
viz_utils.missing_data_plot(gs, df_train)

# %% [markdown]
# # Box Plots

# %%
gs = viz_utils.set_default_plt_display(20, 120,3)
viz_utils.generate_box_plots(gs, df_train)

# %% [markdown]
# # Histograms

# %%
gs = viz_utils.set_default_plt_display(20, 120,3)
viz_utils.generate_histograms(gs, df_train)

# %% [markdown]
# # Correlogram

# %%
viz_utils.generate_correlogram(df_train,20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-0012ceac6594> in <module>()
# ----> 1 viz_utils.generate_scatter_plots(df_train,20)
#
# ~\PycharmProjects\DataScience\src\visualization\utilities.py in generate_scatter_plots(data, size_inches)
#     108     num_col_headers, num_data = get_num_data_and_schema(data)
#     109     p = pd.plotting.scatter_matrix(num_data,  figsize=(size_inches, size_inches))
# --> 110     p.set_axis_bgcolor('g')
#     111     plt.show()
#     112
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_axis_bgcolor'

# %% [markdown]
# # Scatter Plot

# %%
viz_utils.generate_scatter_plots(df_train,20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-0012ceac6594> in <module>()
# ----> 1 viz_utils.generate_scatter_plots(df_train,20)
#
# ~\PycharmProjects\DataScience\src\visualization\utilities.py in generate_scatter_plots(data, size_inches)
#     108     num_col_headers, num_data = get_num_data_and_schema(data)
#     109     p = pd.plotting.scatter_matrix(num_data,  figsize=(size_inches, size_inches))
# --> 110     p.set_axis_bgcolor('g')
#     111     plt.show()
#     112
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_axis_bgcolor'

# %% [markdown]
# # Map Marker

# %%
addresses = ["18 Taunton Road London", "1 Cabot Square London", "2 Triton Square London"]
cities = ["London", "London", "London"]
values = ['100', '5', '50']
data = viz_utils.create_map_data(addresses, cities, values)
viz_utils.get_map_marker(data,tiles="Mapbox Bright", zoom_start=9)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Map Circle

# %%
viz_utils.get_map_circle(data,tiles="Mapbox Bright", zoom_start=9, factor=20)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Word Count

# %%
# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# Create a list of word
text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")
wordcloud = WordCloud(width=480, height=480, stopwords=["Python", "Matplotlib"], max_words=5, colormap="Reds").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
